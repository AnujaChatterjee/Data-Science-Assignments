# %% [markdown]
# Concrete Datasets

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from keras.models import Sequential
from keras.layers import Dense, Activation,Layer,Lambda
import seaborn as sns
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
from sklearn.decomposition import PCA
from mlxtend.plotting import plot_decision_regions
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers import Dense
#from keras.layers.normalization import BatchNormalization
from keras import backend
from keras.optimizers import Adam
from sklearn.metrics import r2_score

# %% [markdown]
# # 1 - Business Problem
#     Prepare a model for strength of concrete data using Neural Networks

# %% [markdown]
# # 2 - Data collection and description

# %%
df = pd.read_csv("C:/Users/Prabinkp/Desktop/ASSIGNEMNETS_DS/concrete.csv")

# %%
df1 = df.copy()
df1
# Out:
#       cement   slag    ash  water  superplastic  coarseagg  fineagg  age  \
# 0      141.3  212.0    0.0  203.5           0.0      971.8    748.5   28
# 1      168.9   42.2  124.3  158.3          10.8     1080.8    796.2   14
# 2      250.0    0.0   95.7  187.4           5.5      956.9    861.2   28
# 3      266.0  114.0    0.0  228.0           0.0      932.0    670.0   28
# 4      154.8  183.4    0.0  193.3           9.1     1047.4    696.7   28
# ...      ...    ...    ...    ...           ...        ...      ...  ...
# 1025   135.0    0.0  166.0  180.0          10.0      961.0    805.0   28
# 1026   531.3    0.0    0.0  141.8          28.2      852.1    893.7    3
# 1027   276.4  116.0   90.3  179.6           8.9      870.1    768.3   28
# 1028   342.0   38.0    0.0  228.0           0.0      932.0    670.0  270
# 1029   540.0    0.0    0.0  173.0           0.0     1125.0    613.0    7
#
#       strength
# 0        29.89
# 1        23.51
# 2        29.22
# 3        45.85
# 4        18.29
# ...        ...
# 1025     13.29
# 1026     41.30
# 1027     44.28
# 1028     55.06
# 1029     52.61
#
# [1030 rows x 9 columns]

# %%
df1.isnull().sum()
# Out:
# cement          0
# slag            0
# ash             0
# water           0
# superplastic    0
# coarseagg       0
# fineagg         0
# age             0
# strength        0
# dtype: int64

# %%
df1.describe().T
# Out:
#                count        mean         std     min      25%      50%  \
# cement        1030.0  281.167864  104.506364  102.00  192.375  272.900
# slag          1030.0   73.895825   86.279342    0.00    0.000   22.000
# ash           1030.0   54.188350   63.997004    0.00    0.000    0.000
# water         1030.0  181.567282   21.354219  121.80  164.900  185.000
# superplastic  1030.0    6.204660    5.973841    0.00    0.000    6.400
# coarseagg     1030.0  972.918932   77.753954  801.00  932.000  968.000
# fineagg       1030.0  773.580485   80.175980  594.00  730.950  779.500
# age           1030.0   45.662136   63.169912    1.00    7.000   28.000
# strength      1030.0   35.817961   16.705742    2.33   23.710   34.445
#
#                    75%     max
# cement         350.000   540.0
# slag           142.950   359.4
# ash            118.300   200.1
# water          192.000   247.0
# superplastic    10.200    32.2
# coarseagg     1029.400  1145.0
# fineagg        824.000   992.6
# age             56.000   365.0
# strength        46.135    82.6

# %% [markdown]
# Outlier Check

# %%
ax = sns.boxplot(df1['strength'])
# Out:
# C:\Users\Prabinkp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# There are 3 Outlier instances in our data

# %%
plt.rcParams["figure.figsize"] = 9,5
plt.figure(figsize=(16,5))
print("Skew: {}".format(df1['strength'].skew()))
print("Kurtosis: {}".format(df1['strength'].kurtosis()))
ax = sns.kdeplot(df1['strength'],shade=True,color='g')
plt.xticks([i for i in range(0,100,10)])
plt.show()
# Out:
# Skew: 0.41697728841071807
# Kurtosis: -0.3137248604469969

# %% [markdown]
# The Data is positively skewed and has negative kurtosis value
#
# Majority of the cement has maximum strengt between 20 and 60

# %%
num_columns = df.select_dtypes(exclude='object').columns.tolist()

# %%
plt.figure(figsize=(18,40))
for i,col in enumerate(num_columns,1):
    plt.subplot(8,4,i)
    sns.kdeplot(df[col],color='g',shade=True)
    plt.subplot(8,4,i+10)
    df[col].plot.box()
plt.tight_layout() 
plt.show()
num_data = df[num_columns]
pd.DataFrame(data=[num_data.skew(),num_data.kurtosis()],index=['skewness','kurtosis'])
# Out:
#             cement      slag       ash     water  superplastic  coarseagg  \
# skewness  0.509481  0.800717  0.537354  0.074628      0.907203  -0.040220
# kurtosis -0.520652 -0.508175 -1.328746  0.122082      1.411269  -0.599016
#
#            fineagg        age  strength
# skewness -0.253010   3.269177  0.416977
# kurtosis -0.102177  12.168989 -0.313725

# %% [markdown]
# Finding Correlation

# %%
corr = df1.corr()
plt.figure(figsize=(10,10))
sns.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 3 - Neural Network Model

# %%
X = df1.iloc[:,0:8]
y = df1.iloc[:,8]

# %%
x_train,x_test,y_train,y_test= train_test_split(X,y, test_size=0.3)

# %%
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
def rmse(y_true, y_pred):
	return backend.sqrt(backend.mean(backend.square(y_pred - y_true), axis=-1))

# %%
model=Sequential()
model.add(Dense(64,input_dim=8,activation = 'relu'))
model.add(Dense(32,activation='relu'))
model.add(Dense(1,activation='linear'))

# %%
opt = Adam(lr=0.0015)
model.compile(optimizer=opt,loss='mean_squared_error',metrics=[rmse])
history = model.fit(x_train,y_train,epochs = 35 ,batch_size=32,validation_split=0.1)
# Out:
# Epoch 1/35
# C:\Users\Prabinkp\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 21/21 [==============================] - 2s 29ms/step - loss: 1508.2825 - rmse: 35.1482 - val_loss: 1472.6235 - val_rmse: 34.0791
# Epoch 2/35
# 21/21 [==============================] - 0s 8ms/step - loss: 1384.6488 - rmse: 33.3952 - val_loss: 1321.8124 - val_rmse: 31.8344
# Epoch 3/35
# 21/21 [==============================] - 0s 8ms/step - loss: 1175.7764 - rmse: 30.3039 - val_loss: 1056.4166 - val_rmse: 27.5722
# Epoch 4/35
# 21/21 [==============================] - 0s 7ms/step - loss: 850.7630 - rmse: 24.8565 - val_loss: 686.4898 - val_rmse: 20.9350
# Epoch 5/35
# 21/21 [==============================] - 0s 12ms/step - loss: 481.0600 - rmse: 17.8328 - val_loss: 358.8029 - val_rmse: 14.4759
# Epoch 6/35
# 21/21 [==============================] - 0s 9ms/step - loss: 260.9891 - rmse: 12.7768 - val_loss: 216.0396 - val_rmse: 11.4376
# Epoch 7/35
# 21/21 [==============================] - 0s 10ms/step - loss: 207.2270 - rmse: 11.5442 - val_loss: 186.9151 - val_rmse: 10.8574
# Epoch 8/35
# 21/21 [==============================] - 0s 9ms/step - loss: 189.8885 - rmse: 11.0506 - val_loss: 178.9162 - val_rmse: 10.6010
# Epoch 9/35
# 21/21 [==============================] - 0s 9ms/step - loss: 179.9314 - rmse: 10.8070 - val_loss: 168.9918 - val_rmse: 10.4089
# Epoch 10/35
# 21/21 [==============================] - 0s 16ms/step - loss: 171.8711 - rmse: 10.5863 - val_loss: 162.1263 - val_rmse: 10.2182
# Epoch 11/35
# 21/21 [==============================] - 0s 8ms/step - loss: 166.2603 - rmse: 10.4094 - val_loss: 154.5748 - val_rmse: 10.0457
# Epoch 12/35
# 21/21 [==============================] - 0s 8ms/step - loss: 159.3382 - rmse: 10.2202 - val_loss: 155.3880 - val_rmse: 10.0005
# Epoch 13/35
# 21/21 [==============================] - 0s 7ms/step - loss: 155.5354 - rmse: 10.1304 - val_loss: 149.8127 - val_rmse: 9.8916
# Epoch 14/35
# 21/21 [==============================] - 0s 6ms/step - loss: 150.9284 - rmse: 9.9668 - val_loss: 143.7787 - val_rmse: 9.7539
# Epoch 15/35
# 21/21 [==============================] - 0s 6ms/step - loss: 146.6825 - rmse: 9.8519 - val_loss: 137.2940 - val_rmse: 9.5742
# Epoch 16/35
# 21/21 [==============================] - 0s 9ms/step - loss: 143.7950 - rmse: 9.7261 - val_loss: 133.0314 - val_rmse: 9.4216
# Epoch 17/35
# 21/21 [==============================] - 0s 9ms/step - loss: 140.6178 - rmse: 9.6537 - val_loss: 129.4878 - val_rmse: 9.3675
# Epoch 18/35
# 21/21 [==============================] - 0s 7ms/step - loss: 137.1177 - rmse: 9.5329 - val_loss: 128.3940 - val_rmse: 9.2665
# Epoch 19/35
# 21/21 [==============================] - 0s 6ms/step - loss: 134.3956 - rmse: 9.4472 - val_loss: 125.5819 - val_rmse: 9.2006
# Epoch 20/35
# 21/21 [==============================] - 0s 7ms/step - loss: 131.3377 - rmse: 9.3185 - val_loss: 120.3686 - val_rmse: 9.0428
# Epoch 21/35
# 21/21 [==============================] - 0s 7ms/step - loss: 128.4191 - rmse: 9.1898 - val_loss: 118.3370 - val_rmse: 8.9245
# Epoch 22/35
# 21/21 [==============================] - 0s 8ms/step - loss: 125.3740 - rmse: 9.0985 - val_loss: 115.6722 - val_rmse: 8.8511
# Epoch 23/35
# 21/21 [==============================] - 0s 8ms/step - loss: 122.5170 - rmse: 8.9916 - val_loss: 112.8866 - val_rmse: 8.7343
# Epoch 24/35
# 21/21 [==============================] - 0s 9ms/step - loss: 119.4045 - rmse: 8.8660 - val_loss: 109.3831 - val_rmse: 8.6175
# Epoch 25/35
# 21/21 [==============================] - 0s 6ms/step - loss: 117.5343 - rmse: 8.7861 - val_loss: 103.9958 - val_rmse: 8.3932
# Epoch 26/35
# 21/21 [==============================] - 0s 8ms/step - loss: 113.4851 - rmse: 8.6343 - val_loss: 102.9779 - val_rmse: 8.2803
# Epoch 27/35
# 21/21 [==============================] - 0s 7ms/step - loss: 110.3537 - rmse: 8.4708 - val_loss: 98.8892 - val_rmse: 8.1894
# Epoch 28/35
# 21/21 [==============================] - 0s 8ms/step - loss: 107.3588 - rmse: 8.3591 - val_loss: 95.6863 - val_rmse: 8.0180
# Epoch 29/35
# 21/21 [==============================] - 0s 12ms/step - loss: 105.8306 - rmse: 8.3009 - val_loss: 92.4849 - val_rmse: 7.9047
# Epoch 30/35
# 21/21 [==============================] - 0s 8ms/step - loss: 101.9697 - rmse: 8.1308 - val_loss: 93.0732 - val_rmse: 7.7854
# Epoch 31/35
# 21/21 [==============================] - 0s 8ms/step - loss: 99.4490 - rmse: 7.9955 - val_loss: 87.2775 - val_rmse: 7.6685
# Epoch 32/35
# 21/21 [==============================] - 0s 12ms/step - loss: 97.3560 - rmse: 7.8594 - val_loss: 88.1845 - val_rmse: 7.5667
# Epoch 33/35
# 21/21 [==============================] - 0s 11ms/step - loss: 94.3169 - rmse: 7.7464 - val_loss: 86.0837 - val_rmse: 7.5039
# Epoch 34/35
# 21/21 [==============================] - 0s 6ms/step - loss: 92.3708 - rmse: 7.6942 - val_loss: 84.6784 - val_rmse: 7.4393
# Epoch 35/35
# 21/21 [==============================] - 0s 7ms/step - loss: 89.2411 - rmse: 7.5187 - val_loss: 81.2005 - val_rmse: 7.3225

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 64)                576
#
#  dense_3 (Dense)             (None, 32)                2080
#
#  dense_4 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 2,689
# Trainable params: 2,689
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 4 - Conclusion

# %%
y_predict = model.predict(x_test)
r2_score(y_test,y_predict)
# Out:
# 10/10 [==============================] - 0s 3ms/step
# 0.6262408023712196

# %%
plt.plot(history.history['rmse'])
plt.plot(history.history['val_rmse'])
plt.title('Root Mean Squared Error')
plt.ylabel('rmse')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.savefig('4.png')
plt.show()

# %% [markdown]
# The model has an acceptable score
